# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielIramain/ped-unahur/blob/practico/PED_(CG)_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <img src="https://img2.freepng.es/20180331/zoe/kisspng-book-report-clip-art-report-5abfb471d3af30.0282813815225130098671.jpg" width="60" height="60"> **Procesamiento y Exploración de Datos 2023 - Trabajo Final** <img src="https://img2.freepng.es/20180331/zoe/kisspng-book-report-clip-art-report-5abfb471d3af30.0282813815225130098671.jpg"  width="60" height="60">
#
#
# El propósito del Trabajo Práctico final es evaluar todos los contenidos del curso. La entrega será individual y debe ser subida **antes del 24/04/2023** al campus.

# %% [markdown]
# #Titanic
# El hundimiento del Titanic es uno de los naufragios más infames de la historia. El 15 de abril de 1912, durante su viaje inaugural, el RMS Titanic, ampliamente considerado como "insumergible", se hundió después de chocar con un iceberg. Desafortunadamente, no había suficientes botes salvavidas para todos a bordo, lo que resultó en la muerte de 1502 de los 2224 pasajeros y tripulantes.
#
# Si bien hubo algún elemento de suerte involucrado en la supervivencia, parece que algunos grupos de personas tenían más probabilidades de sobrevivir que otros. En un próximo curso aprenderan a predecir la supervivencia del Titanic con las variables que tienen. Por el momento pueden realizar un analisis explotarorio.
#
# Le pedimos que investiguen los datos de  los pasajeros (es decir, nombre, edad, sexo, clase socioeconómica, etc.).

# %% [markdown]
# ##Exportar las librerías de Python que van a utilizar a lo largo del programa

# %%
#Importar librerias
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt


# Montar Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Importar los datos que van a utilizar dentro de su análisis

# %% [markdown]
# En esta [carpeta](https://drive.google.com/drive/folders/1jxmGWB7n8dVxLEvScc43ejRdpTx1r84_?usp=share_link) se encuentran los datos que van a usar.

# %% [markdown]
# En la carpeta podran ver que se encuentran tres archivos:
#
#
# *   test_survived.csv
# *   test.csv
# *   train.csv

# %% [markdown]
# Los datos separados en dos grupos: test y train, es distribución que se utilizará más adelante (proximo curso) cuando entrenemos un modelo con los datos (train) y validemos al mismo con los datos (test). En este momento los usaremos en un solo archivo que reuna todos los datos.

# %% [markdown]
# Con el archivo `test_survided.csv` deben completar los datos del archivo `test.csv` agregando la columna `Survived` que corresponde a si sobrevivio o no. Esto deben hacerlo por código.

# %% [markdown]
# **Ayuda**: pueden usar la función `pd.merge()`.

# %% [markdown]
# Una vez completado el dataset **test**, como se mencionó anteriormente, ustedes deberán usar ambos datasets. Para unir ambas tablas deben hacerlo por codigo.
#
#
# **Ayuda**: pueden usar la función `pd.concat()`

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %%
test_survived = pd.read_csv('/content/drive/MyDrive/UNAHUR/00_Procesamiento y exploracion de datos (PED)/00_trabajo final/TitanicDataset/test_survived.csv')
test = pd.read_csv('/content/drive/MyDrive/UNAHUR/00_Procesamiento y exploracion de datos (PED)/00_trabajo final/TitanicDataset/test.csv')

# %%
df = pd.merge(test, test_survived[['PassengerId','Survived']], on='PassengerId', how='left')

# %%
df= df[["PassengerId","Survived","Pclass","Name","Sex","Age","SibSp","Parch","Ticket","Fare","Cabin","Embarked"]]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %% [markdown]
# ## Significado de los atributos
#
# *   **Survived**:	Supervivencia	(0 = No, 1 = Sí)
# *   **Pclase**:	clase de boleto	(1 = 1°, 2 = 2°, 3 = 3°)
# *   **Sex**:	Sexo
# *   **Age**: Edad en años
# *   **Sibsp**: cantidad de hermanos/cónyuges a bordo del Titanic
# *   **Parch**: cantidad de padres/hijos a bordo del Titanic
# *   **Ticket**: Numero de ticket
# *   **Fare**:	tarifa de pasajero
# *   **Cabin**:	Número de cabina
# *   **Embarked**:	Puerto de embarque	(C = Cherburgo, Q = Queenstown, S = Southampton)
# *   **PassengerId**:	Id del pasajero

# %% [markdown]
# ##Ejericio 1
#
# Leer los archivos cvs que conforman la tabla titanic y hacer una análisis exploratorio de sus atributos.
#
# 1.   Ver los tipos de datos con la función `info()`y explicar
#
# 2.   Ver los datos estadísticos con la función `describe()`y explicar
#
# 3.   Hacer un histograma de las principales variables numéricas continuas utilice bins adecuados. Para el resto de las variables realice un grafico que crea adecuado.

# %%
#Dimension y nombre de las columnas
dimension = df.shape
columnas = df.columns
lista_columnas = []

for i in range(len(columnas)):
  lista_columnas.append(columnas[i])

print('===/Dimension de la tabla/===')
print(f'Filas: {dimension[0]} \nColumnas {dimension[1]}')
print('===/Nombre de las columnas/===')
print(lista_columnas)
# Out:
# ===/Dimension de la tabla/===
# Filas: 418
# Columnas 12
# ===/Nombre de las columnas/===
# ['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Survived']

# %%
#Leer el archivo train.csv
train = pd.read_csv('/content/drive/MyDrive/UNAHUR/00_Procesamiento y exploracion de datos (PED)/00_trabajo final/TitanicDataset/train.csv')

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
#Dimension y nombres de las columnas
dimension_train = train.shape
columnas_train = train.columns
lista_columnas_train = []

for i in range(len(columnas_train)):
  lista_columnas_train.append(columnas_train[i])

print('===/Dimension de la tabla/===')
print(f'Filas: {dimension_train[0]} \nColumnas {dimension_train[1]}')
print('===/Nombre de las columnas/===')
print(lista_columnas_train)
# Out:
# ===/Dimension de la tabla/===
# Filas: 891
# Columnas 12
# ===/Nombre de las columnas/===
# ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %%
#Verifico el tipo de datos en ambos dataset
print(df.info(), '\n')
print(train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 42.5+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None

# %%
#Junto ambos datasets
###Parameters:
####objs: a sequence or mapping of Series or DataFrame objects
df = pd.concat([df, train])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 886                         Montvila, Rev. Juozas    male  27.0      0      0
# 887                  Graham, Miss. Margaret Edith  female  19.0      0      0
# 888      Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1      2
# 889                         Behr, Mr. Karl Howell    male  26.0      0      0
# 890                           Dooley, Mr. Patrick    male  32.0      0      0
#
#          Ticket     Fare Cabin Embarked
# 0        330911   7.8292   NaN        Q
# 1        363272   7.0000   NaN        S
# 2        240276   9.6875   NaN        Q
# 3        315154   8.6625   NaN        S
# 4       3101298  12.2875   NaN        S
# ..          ...      ...   ...      ...
# 886      211536  13.0000   NaN        S
# 887      112053  30.0000   B42        S
# 888  W./C. 6607  23.4500   NaN        S
# 889      111369  30.0000  C148        C
# 890      370376   7.7500   NaN        Q
#
# [1309 rows x 12 columns]

# %%
#Verifico las estadísticas del dataset
df.describe()
# Out:
#        PassengerId     Survived       Pclass          Age        SibSp  \
# count  1309.000000  1309.000000  1309.000000  1046.000000  1309.000000
# mean    655.000000     0.377387     2.294882    29.881138     0.498854
# std     378.020061     0.484918     0.837836    14.413493     1.041658
# min       1.000000     0.000000     1.000000     0.170000     0.000000
# 25%     328.000000     0.000000     2.000000    21.000000     0.000000
# 50%     655.000000     0.000000     3.000000    28.000000     0.000000
# 75%     982.000000     1.000000     3.000000    39.000000     1.000000
# max    1309.000000     1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare
# count  1309.000000  1308.000000
# mean      0.385027    33.295479
# std       0.865560    51.758668
# min       0.000000     0.000000
# 25%       0.000000     7.895800
# 50%       0.000000    14.454200
# 75%       0.000000    31.275000
# max       9.000000   512.329200

# %%
#Graficos
fig, axes = plt.subplots(1, 2)

df.hist('Age', bins=8, ax=axes[0])
df.hist('Fare', bins=8, ax=axes[1])
# Out:
# array([<Axes: title={'center': 'Fare'}>], dtype=object)

# %% [markdown]
# ##Ejercicio 2
#
# Defina otro dataframe cumpliendo lo siguiente:
#
# *   Imputar los datos faltantes y valores atípicos, descartar el resto.
#
# *   Reemplazar los valores de las columnas no numéricas por valores numéricos. (Por ejemplo si es mujer poner 1, si es varón poner 0)
#
# Observacion: Un valor atípico es aquel que dista mas de 2 desvios standard para el contexto de este ejercicio.

# %%
#Verifico los datos faltantes de los dataset
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %%
#Cambio los datos de sexos en números
df['Sex'].replace({'male': 0, 'female': 1}, inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name  Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    0  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)    1  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    0  62.0      0      0
# 3                                Wirz, Mr. Albert    0  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1  22.0      1      1
# ..                                            ...  ...   ...    ...    ...
# 886                         Montvila, Rev. Juozas    0  27.0      0      0
# 887                  Graham, Miss. Margaret Edith    1  19.0      0      0
# 888      Johnston, Miss. Catherine Helen "Carrie"    1   NaN      1      2
# 889                         Behr, Mr. Karl Howell    0  26.0      0      0
# 890                           Dooley, Mr. Patrick    0  32.0      0      0
#
#          Ticket     Fare Cabin Embarked
# 0        330911   7.8292   NaN        Q
# 1        363272   7.0000   NaN        S
# 2        240276   9.6875   NaN        Q
# 3        315154   8.6625   NaN        S
# 4       3101298  12.2875   NaN        S
# ..          ...      ...   ...      ...
# 886      211536  13.0000   NaN        S
# 887      112053  30.0000   B42        S
# 888  W./C. 6607  23.4500   NaN        S
# 889      111369  30.0000  C148        C
# 890      370376   7.7500   NaN        Q
#
# [1309 rows x 12 columns]

# %%
#Cambio los datos de embarque en números
df['Embarked'].replace({'C': 0, 'Q': 1, 'S': 2}, inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name  Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    0  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)    1  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    0  62.0      0      0
# 3                                Wirz, Mr. Albert    0  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1  22.0      1      1
# ..                                            ...  ...   ...    ...    ...
# 886                         Montvila, Rev. Juozas    0  27.0      0      0
# 887                  Graham, Miss. Margaret Edith    1  19.0      0      0
# 888      Johnston, Miss. Catherine Helen "Carrie"    1   NaN      1      2
# 889                         Behr, Mr. Karl Howell    0  26.0      0      0
# 890                           Dooley, Mr. Patrick    0  32.0      0      0
#
#          Ticket     Fare Cabin  Embarked
# 0        330911   7.8292   NaN       1.0
# 1        363272   7.0000   NaN       2.0
# 2        240276   9.6875   NaN       1.0
# 3        315154   8.6625   NaN       2.0
# 4       3101298  12.2875   NaN       2.0
# ..          ...      ...   ...       ...
# 886      211536  13.0000   NaN       2.0
# 887      112053  30.0000   B42       2.0
# 888  W./C. 6607  23.4500   NaN       2.0
# 889      111369  30.0000  C148       0.0
# 890      370376   7.7500   NaN       1.0
#
# [1309 rows x 12 columns]

# %%
#Reemplazo los datos faltantes en la tarifa
df['Fare'].fillna(0, inplace=True)

# %%
#Reemplazo los datos faltantes en la edad
df['Age'].fillna(23, inplace=True)
# Out:
# 23.87751718869366

# %% [markdown]
# Se opta por eliminar la columna de cabina debido a la cantidad de datos faltantes.

# %%
#Elimino las columnas que considero que no son necesarias para el analisis
df.drop(columns=['Cabin'], inplace=True)

# %%
#Elimino las columnas que considero que no son necesarias para el analisis
df.drop(columns=['Ticket', 'Pclass'], inplace=True)

# %%
#Se elimina las filas con los datos perdidos
df.dropna(inplace=True)

# %%
#Verifico los datos
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# ##Ejericio 3
#
#
# *   Volver a realizar los histogramas y un boxplot de cada columna indicando que columnas cambiaron su "distribución" en un sentindo visible gráficamente
#
# *   Comentar brevemente porqué una mala imputación de datos (i.e sustituir la edad por 0) puede llevar a un análisis incorrecto de la información

# %%
#Graficos
fig, axes = plt.subplots(1, 3)

df.hist('Age', bins=8, ax=axes[0])
df.hist('Fare', bins=8, ax=axes[1])

plt.boxplot(df['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fa0828f0790>,
#   <matplotlib.lines.Line2D at 0x7fa0828f0af0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fa0828f1ea0>,
#   <matplotlib.lines.Line2D at 0x7fa08260c700>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fa0828f2f50>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fa08260c790>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fa08260e4a0>],
#  'means': []}

# %%
plt.boxplot(df['Fare'], vert=0)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fa082a5aef0>,
#   <matplotlib.lines.Line2D at 0x7fa082a5b190>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fa082a5b430>,
#   <matplotlib.lines.Line2D at 0x7fa082a5b6d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fa082a5ac50>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fa082a5b970>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fa082a5bc10>],
#  'means': []}

# %%
df['Sex'].value_counts().plot.pie(labels=['male', 'female'],
                                  title='Sex distribution',
                                  legend=True, autopct = "%0.0f %%")
# Out:
# <Axes: title={'center': 'Sex distribution'}, ylabel='Sex'>

# %% [markdown]
# La columna de edad cambió su distribución visiblemente, esto se debe a la limpieza de datos efectuada en el paso anterior. Por otro lado, si la imputación de datos es errónea, los estadísticos de cada columna pueden arrojar valores que nos lleven a conclusiones equivocadas.

# %% [markdown]
# ##Ejericio 4
#
#
# *   Con el último set de datos utilizar el coeficiente de correlación de Pearson y analizar si existe correlación y de que tipo entre las distintas variables.
#
# *   **Punto extra**: realice un mapa de la correlación de Pearson (comente que ve) (Ayuda: heatmap)
